# %%
import yfinance as yf
import quandl as qu
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = yf.download('AAPL', '2019-01-01', '2020-05-13')
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

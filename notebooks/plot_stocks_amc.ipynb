# %% [markdown]
# # Plot some stocks using yfinance

# %%
import yfinance as yf
import quandl as qu
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Use yf download

# %%
data = yf.download(['AAPL', 'SPY', 'CL=F'], '2019-01-01', '2020-05-13')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data[('Close', 'AAPL')].plot(label='AAPL')
data[('Close', 'SPY')].plot(label='SPY')
data[('Close', 'CL=F')].plot(label='OIL')
plt.title('AAPL, SPY, OIL 2019 to 2020-05-13')
plt.legend()

# %% [markdown]
# ## Use yf Ticker

# %%
aapl = yf.Ticker("AAPL")

# %%
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...

# %%
aapl.history(period="max")
# Out:
#               Open    High     Low   Close     Volume  Dividends  Stock Splits
# Date
# 1980-12-12    0.41    0.41    0.41    0.41  117258400        0.0           0.0
# 1980-12-15    0.39    0.39    0.38    0.38   43971200        0.0           0.0
# 1980-12-16    0.36    0.36    0.36    0.36   26432000        0.0           0.0
# 1980-12-17    0.37    0.37    0.37    0.37   21610400        0.0           0.0
# 1980-12-18    0.38    0.38    0.38    0.38   18362400        0.0           0.0
# ...            ...     ...     ...     ...        ...        ...           ...
# 2020-05-21  318.66  320.89  315.87  316.85   25672200        0.0           0.0
# 2020-05-22  315.77  319.23  315.35  318.89   20450800        0.0           0.0
# 2020-05-26  323.50  324.24  316.50  316.73   31380500        0.0           0.0
# 2020-05-27  316.14  318.71  313.09  318.11   28211100        0.0           0.0
# 2020-05-28  316.77  323.35  315.63  322.55   20620383        0.0           0.0
#
# ...

# %%
aapl.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.quarterly_financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.cashflow
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.sustainability
# Out:
#                                      Value
# 2020-3
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                             13
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                         0
# peerCount                               57
# governanceScore                      10.26
# environmentPercentile                    0
# animalTesting                        False
# tobacco                              False
# totalEsg                             23.82
# highestControversy                       3
# esgPerformance                    AVG_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
aapl.calendar
# Out:
#                                     0                    1
# Earnings Date     2020-07-28 00:00:00  2020-08-03 00:00:00
# Earnings Average                    2                    2
# Earnings Low                     1.55                 1.55
# Earnings High                    2.43                 2.43
# Revenue Average           51390200000          51390200000
# Revenue Low               42796000000          42796000000
# Revenue High              54517500000          54517500000

# %%
aapl.recommendations
# Out:
#                                   Firm    To Grade From Grade Action
# Date
# 2012-02-09 08:17:00  Canaccord Genuity         Buy              main
# 2012-03-08 07:33:00     FBN Securities  Outperform              main
# 2012-03-13 06:08:00          Jefferies         Buy              main
# 2012-03-14 06:13:00     Morgan Stanley  Overweight              main
# 2012-03-14 08:21:00  Canaccord Genuity         Buy              main
# ...                                ...         ...        ...    ...
# 2020-05-01 14:33:31  Canaccord Genuity         Buy              main
# 2020-05-01 14:34:20        DA Davidson         Buy              main
# 2020-05-12 12:43:18            Wedbush  Outperform              main
# 2020-05-27 11:37:26      Deutsche Bank         Buy              main
# 2020-05-27 15:22:19  B of A Securities         Buy              main
#
# [698 rows x 4 columns]

# %%
aapl.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  336728608    2020-03-30  0.0777
# 1                     Blackrock Inc.  274684501    2020-03-30  0.0634
# 2            Berkshire Hathaway, Inc  245155566    2020-03-30  0.0566
# 3           State Street Corporation  180558954    2020-03-30  0.0417
# 4                Advisor Group, Inc.  116768396    2020-03-30  0.0269
# 5                           FMR, LLC   93376233    2020-03-30  0.0215
# 6      Geode Capital Management, LLC   64178586    2020-03-30  0.0148
# 7      Price (T.Rowe) Associates Inc   56203762    2020-03-30  0.0130
# 8         Northern Trust Corporation   53859611    2020-03-30  0.0124
# 9  Norges Bank Investment Management   46856273    2019-12-30  0.0108
#
#          Value
# 0  85626717728
# 1  69849521759
# 2  62340608878
# 3  45914336412
# 4  29693035418
# 5  23744642289
# 6  16319972633
# 7  14292054638
# 8  13695960481
# 9  13759344566

# %% [markdown]
# ## Multiple Tickers

# %%
tickers = yf.Tickers('msft aapl goog')
# ^ returns a named tuple of Ticker objects
tickers.tickers.AAPL.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...
